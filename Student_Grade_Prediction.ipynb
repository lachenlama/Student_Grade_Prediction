# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("student-mat.csv")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
plt.figure(figsize=(16,6))
sns.distplot(a=df['age'], kde=False)
plt.xlabel("Age", fontsize=15)
plt.ylabel("Number of students", fontsize=15)
plt.title("Distribution of Age of students", fontsize=20)
# Out:
# c:\users\win10\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Age of students')

# %% [markdown]
# We can see that there are more students with the age of 15, 16 and 17 in the class.
#
# ---

# %%
plt.figure(figsize=(16,6))
labels = ['Female', 'Male']
plt.title("Male Female count in class", fontsize=20)
plt.pie(df.sex.value_counts(), labels=labels, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x24d5bb55ac0>,
# ...
#  [Text(-0.09175509895664602, 1.096166502779325, 'Female'),
#   Text(0.09175520158716051, -1.096166494188588, 'Male')],
#  [Text(-0.050048235794534185, 0.5979090015159955, '53%'),
#   Text(0.05004829177481482, -0.5979089968301389, '47%')])

# %%
plt.figure(figsize=(16,8))
sns.barplot(x=df['sex'], y=df['G3'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='G3'>

# %% [markdown]
# From the above bars we can see that the Males have scored higher in G3 compared to females in a class where more than 50% are females.
#
# ---

# %%
plt.figure(figsize=(16,10))
plt.title("Studytime-Grades Graph", fontsize=20)
plt.xlabel("Grades in different Semesters", fontsize=15)
plt.ylabel("Studytime", fontsize=15)
sns.lineplot(x=df['G1'], y=df['studytime'], label='G1', ci=None)
sns.lineplot(x=df['G2'], y=df['studytime'], label='G2', ci=None)
sns.lineplot(x=df['G3'], y=df['studytime'], label='G3', ci=None)
# Out:
# <AxesSubplot:title={'center':'Studytime-Grades Graph'}, xlabel='Grades in different Semesters', ylabel='Studytime'>

# %% [markdown]
# We can see the amout of time a student spends in studies and the Grade he/she acquires depending on the time spent in studying.
#
# ---

# %%
plt.figure(figsize=(16,6))
sns.lineplot(x=df['G3'], y=df['absences'])
plt.xlabel("G3", fontsize=15)
plt.ylabel("absences", fontsize=15)
plt.title("Absence-Grade Graph", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Absence-Grade Graph')

# %% [markdown]
# We can see from the above graph that students who are absent often have scored less marks compared to others.
#
# ---

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=df['failures'], y=df['G3'])
plt.xlabel("Failures", fontsize=15)
plt.ylabel("Grade", fontsize=15)
# Out:
# Text(0, 0.5, 'Grade')

# %% [markdown]
# From the above Graph we can see that students who have failed in previous classes have not performed well
#
# ---

# %%
fig,(ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16,6))
ax1.bar(df['Fedu'], df['G3'], color= 'Orange')
ax1.set_xlabel("Father Education")
ax1.set_ylabel("Grade of Child")
ax2.bar(df['Medu'], df['G3'])
ax2.set_xlabel("Mother Education")
ax2.set_ylabel("Grade of Child")
# Out:
# Text(0, 0.5, 'Grade of Child')

# %% [markdown]
# Here, we can see that students whose parent's have higher education scored better marks.
#
# ---

# %%
fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16,6))
ax1.bar(df['Dalc'], df['G3'], color='Orange')
ax1.set_xlabel("Daily Alcohol consumption")
ax1.set_ylabel("Grade")
ax2.bar(df['Walc'], df['G3'])
ax2.set_xlabel("Weekend Alcohol consumption")
ax2.set_ylabel("Grade")
# Out:
# Text(0, 0.5, 'Grade')

# %% [markdown]
# The less alcohol a student consumes daily or weekly the higher the grades of that student
#
# ---

# %%
fig,((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(16,12))
ax1.bar(df['internet'], df['G3'], color='Orange')
ax1.set_xlabel("Internet availability")
ax1.set_ylabel("Grade")

ax2.bar(df['romantic'], df['G3'])
ax2.set_xlabel("In a relationship")
ax2.set_ylabel("Grade")

ax3.bar(df['nursery'], df['G3'], color='Magenta')
ax3.set_xlabel("Attended Nursery")
ax3.set_ylabel("Grade")

ax4.bar(df['higher'], df['G3'], color='Green')
ax4.set_xlabel("Opts for higher education")
ax4.set_ylabel("Grade")
# Out:
# Text(0, 0.5, 'Grade')

# %% [markdown]
# From above we can observe, <br>
# In Graph (1,2) students who have internet connection scored more marks. <br>
# In Graph (2,2) students who are in relationship scored less marks. <br>
# In Graph (1,1) stuents who attended nursery scored higher. <br>
# In Graph (2,1) students who want higher education scored higher.
#
# ---

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
features = ['Medu', 'Fedu', 'studytime', 'Dalc', 'G1', 'G2', 'failures', 'absences']
y = df['G3']
X = df[features]

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %%
lr = LinearRegression()
lr_model = lr.fit(train_X, train_y)
lr_model_pred = lr.predict(val_X)

# %%
print("Mean Absolute Error: ", mean_absolute_error(val_y, lr_model_pred))
# Out:
# Mean Absolute Error:  1.182752541281914

# %%
print("Accuracy: ", lr.score(val_X, val_y))
# Out:
# Accuracy:  0.7755151808968258
